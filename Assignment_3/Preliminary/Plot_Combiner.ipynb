# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
from PIL import Image

# %%
img1=Image.open("Report Images/Step 2/RGP/HEART/RGP_RECONSTRUCTION_ERROR_2.png")
img2=Image.open("Report Images/Step 2/RGP/HEART/RGP_PAIRWISE_ERROR_2.png")
#img3=Image.open("Report Images/Step 2/ISOMAP/HEART/Distance Measure Isomap.png")
#img4=Image.open("Report Images/Step 1/HEART/GMM/BIC.png")
#img5=Image.open("Report Images/Step 1/FMINST/GMM/SC_SCORE.png")

# %%
fig, axes = plt.subplots(1, 2)
fig.set_size_inches(8*2, 15)

plt.suptitle('RGP EXPERIMENTATION (HEART)')

axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

# axes[2].imshow(img3)
# axes[2].axis('off')


# axes[3].imshow(img4)
# axes[3].axis('off')

#axes[4].imshow(img4)
# axes[4].axis('off')

plt.tight_layout()
plt.subplots_adjust(top=1.60)
plt.show()

# %%
img1=Image.open("Report Images/Step 3/HEART/ISOMAP/SC.png")
img2=Image.open("Report Images/Step 3/HEART/ISOMAP/WCSS.png")
img3=Image.open("Report Images/Step 3/HEART/ISOMAP/AIC.png")
img4=Image.open("Report Images/Step 3/HEART/ISOMAP/BIC.png")
#img5=Image.open("Report Images/Step 1/FMINST/GMM/SC_SCORE.png")

# %%
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(8*4, 5)

plt.suptitle('HEART EM ISOMAP N-Clustering Experimentation')

axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

axes[2].imshow(img3)
axes[2].axis('off')
#axes[2].set_title('First 12 Components')

axes[3].imshow(img4)
axes[3].axis('off')

#axes[4].imshow(img4)
# axes[4].axis('off')

plt.tight_layout()
#plt.subplots_adjust(top=1.5)
plt.show()

# %%
img1=Image.open("Report Images/Step 3/FMINST/PCA_RES_VIZ_EM.png")
img2=Image.open("Report Images/Step 3/FMINST/ISO_RES_VIZ_EM.png")
#img3=Image.open("Report Images/Step 1/FMINST/KMODES/Res_Viz.png")
#img4=Image.open("Report Images/Step 1/HEART/GMM/BIC.png")
#img5=Image.open("Report Images/Step 1/FMINST/GMM/SC_SCORE.png")

# %%
fig, axes = plt.subplots(1, 2)
fig.set_size_inches(55, 55)

#plt.suptitle('HEART EM CLUSTERING PAIR PLOTS')

axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

# axes[2].imshow(img3)
# axes[2].axis('off')


# axes[3].imshow(img4)
# axes[3].axis('off')

#axes[4].imshow(img4)
# axes[4].axis('off')

plt.tight_layout()
#plt.subplots_adjust(top=1.58)
plt.show()
